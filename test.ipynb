# %%
from DataAggregate.DataAggregate import DataAggregate

da = DataAggregate()

# %%
from data_sources.ProFootballReference import ProFootballReference

pfr = ProFootballReference()

# %%
pfr.get_data(['2025'])
# Out:
# https://www.pro-football-reference.com/teams/crd/2025/gamelog/
# https://www.pro-football-reference.com/teams/crd/2025/gamelog/
# No playoff data found for crd in 2025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pfr.get_data(['2025'])
#
# File ~/Desktop/bet/data_sources/ProFootballReference.py:227, in ProFootballReference.get_data(self, seasons)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:
